# %% [markdown]
# <a href="https://colab.research.google.com/github/hafsaTaoufiq/CatchioAPP/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install TensorFlow==1.15
# Out:
# Collecting TensorFlow==1.15
#   Downloading https://files.pythonhosted.org/packages/3f/98/5a99af92fb911d7a88a0005ad55005f35b4c1ba8d75fba02df726cd936e6/tensorflow-1.15.0-cp36-cp36m-manylinux2010_x86_64.whl (412.3MB)
#      |████████████████████████████████| 412.3MB 43kB/s
# Collecting keras-applications>=1.0.8
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 5.8MB/s
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 34.5MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from TensorFlow==1.15) (0.34.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from TensorFlow==1.15) (1.30.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from TensorFlow==1.15) (1.18.5)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from TensorFlow==1.15) (0.9.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from TensorFlow==1.15) (1.12.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from TensorFlow==1.15) (3.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from TensorFlow==1.15) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from TensorFlow==1.15) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from TensorFlow==1.15) (0.2.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from TensorFlow==1.15) (3.12.4)
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 37.3MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from TensorFlow==1.15) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from TensorFlow==1.15) (0.8.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->TensorFlow==1.15) (2.10.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->TensorFlow==1.15) (49.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->TensorFlow==1.15) (3.2.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->TensorFlow==1.15) (1.0.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->TensorFlow==1.15) (1.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->TensorFlow==1.15) (3.1.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=71cdc0d788636cae5e5bbeedf78795539805e5927b3d8498d1f0ca25a2826f07
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.11.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# Installing collected packages: keras-applications, gast, tensorboard, tensorflow-estimator, TensorFlow
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: tensorflow 2.3.0
#     Uninstalling tensorflow-2.3.0:
#       Successfully uninstalled tensorflow-2.3.0
# Successfully installed TensorFlow-1.15.0 gast-0.2.2 keras-applications-1.0.8 tensorboard-1.15.0 tensorflow-estimator-1.15.1

# %%
# !pip install keras==2.2.5
# Out:
# Collecting keras==2.2.5
#   Downloading https://files.pythonhosted.org/packages/f8/ba/2d058dcf1b85b9c212cc58264c98a4a7dd92c989b798823cc5690d062bb2/Keras-2.2.5-py2.py3-none-any.whl (336kB)
#      |████████████████████████████████| 337kB 3.3MB/s
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.5) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.5) (1.18.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.5) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.5) (1.4.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.5) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.5) (1.1.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.5) (2.10.0)
# Installing collected packages: keras
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.2.5

# %%
# !pip install -U scikit-image==0.16.2
# Out:
# Requirement already up-to-date: scikit-image==0.16.2 in /usr/local/lib/python3.6/dist-packages (0.16.2)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image==0.16.2) (1.1.1)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image==0.16.2) (7.0.0)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image==0.16.2) (2.4)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image==0.16.2) (1.4.1)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image==0.16.2) (2.4.1)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image==0.16.2) (3.2.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from PyWavelets>=0.4.0->scikit-image==0.16.2) (1.18.5)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image==0.16.2) (4.4.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.16.2) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.16.2) (2.4.7)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.16.2) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.16.2) (1.2.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.1->matplotlib!=3.0.0,>=2.0.0->scikit-image==0.16.2) (1.15.0)

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.0'

# %%
# !git clone https://github.com/matterport/Mask_RCNN.git
# Out:
# Cloning into 'Mask_RCNN'...
# remote: Enumerating objects: 956, done.
# remote: Total 956 (delta 0), reused 0 (delta 0), pack-reused 956
# Receiving objects: 100% (956/956), 116.77 MiB | 30.07 MiB/s, done.
# Resolving deltas: 100% (565/565), done.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/Mask_RCNN
# Out:
# /content/Mask_RCNN

# %%
from os import listdir
from xml.etree import ElementTree
from numpy import zeros
from numpy import asarray
from numpy import expand_dims
from numpy import mean
from mrcnn.config import Config
from mrcnn.model import MaskRCNN
from mrcnn.utils import Dataset
from mrcnn.utils import compute_ap
from mrcnn.model import load_image_gt
from mrcnn.model import mold_image
# Out:
# Using TensorFlow backend.

# %%
from distutils.dir_util import copy_tree
##copy_tree("/a/b/c", "/content/Mask_RCNN")
copy_tree("/content/drive/My Drive/images_1","/content/Mask_RCNN/images_1")
# Out:
# ['/content/Mask_RCNN/images_1/290.png',
#  '/content/Mask_RCNN/images_1/278.png',
#  '/content/Mask_RCNN/images_1/273.png',
#  '/content/Mask_RCNN/images_1/279.png',
#  '/content/Mask_RCNN/images_1/296.png',
#  '/content/Mask_RCNN/images_1/307.png',
#  '/content/Mask_RCNN/images_1/295.png',
#  '/content/Mask_RCNN/images_1/298.png',
#  '/content/Mask_RCNN/images_1/312.png',
#  '/content/Mask_RCNN/images_1/315.png',
#  '/content/Mask_RCNN/images_1/303.png',
#  '/content/Mask_RCNN/images_1/306.png',
#  '/content/Mask_RCNN/images_1/305.png',
#  '/content/Mask_RCNN/images_1/297.png',
#  '/content/Mask_RCNN/images_1/309.png',
#  '/content/Mask_RCNN/images_1/311.png',
#  '/content/Mask_RCNN/images_1/316.png',
#  '/content/Mask_RCNN/images_1/302.png',
#  '/content/Mask_RCNN/images_1/308.png',
#  '/content/Mask_RCNN/images_1/299.png',
#  '/content/Mask_RCNN/images_1/317.png',
#  '/content/Mask_RCNN/images_1/304.png',
#  '/content/Mask_RCNN/images_1/310.png',
#  '/content/Mask_RCNN/images_1/313.png',
#  '/content/Mask_RCNN/images_1/301.png',
#  '/content/Mask_RCNN/images_1/332.png',
#  '/content/Mask_RCNN/images_1/327.png',
#  '/content/Mask_RCNN/images_1/325.png',
#  '/content/Mask_RCNN/images_1/321.png',
#  '/content/Mask_RCNN/images_1/330.png',
#  '/content/Mask_RCNN/images_1/333.png',
#  '/content/Mask_RCNN/images_1/339.png',
#  '/content/Mask_RCNN/images_1/323.png',
#  '/content/Mask_RCNN/images_1/319.png',
#  '/content/Mask_RCNN/images_1/318.png',
#  '/content/Mask_RCNN/images_1/331.png',
#  '/content/Mask_RCNN/images_1/322.png',
#  '/content/Mask_RCNN/images_1/338.png',
#  '/content/Mask_RCNN/images_1/335.png',
#  '/content/Mask_RCNN/images_1/336.png',
#  '/content/Mask_RCNN/images_1/334.png',
#  '/content/Mask_RCNN/images_1/337.png',
#  '/content/Mask_RCNN/images_1/320.png',
#  '/content/Mask_RCNN/images_1/329.png',
#  '/content/Mask_RCNN/images_1/324.png',
#  '/content/Mask_RCNN/images_1/340.png',
#  '/content/Mask_RCNN/images_1/326.png',
#  '/content/Mask_RCNN/images_1/358.png',
#  '/content/Mask_RCNN/images_1/352.png',
#  '/content/Mask_RCNN/images_1/348.png',
#  '/content/Mask_RCNN/images_1/347.png',
#  '/content/Mask_RCNN/images_1/354.png',
#  '/content/Mask_RCNN/images_1/350.png',
#  '/content/Mask_RCNN/images_1/359.png',
#  '/content/Mask_RCNN/images_1/342.png',
#  '/content/Mask_RCNN/images_1/341.png',
#  '/content/Mask_RCNN/images_1/345.png',
#  '/content/Mask_RCNN/images_1/344.png',
#  '/content/Mask_RCNN/images_1/349.png',
#  '/content/Mask_RCNN/images_1/357.png',
#  '/content/Mask_RCNN/images_1/355.png',
#  '/content/Mask_RCNN/images_1/351.png',
#  '/content/Mask_RCNN/images_1/343.png',
#  '/content/Mask_RCNN/images_1/356.png',
#  '/content/Mask_RCNN/images_1/353.png',
#  '/content/Mask_RCNN/images_1/346.png',
#  '/content/Mask_RCNN/images_1/369.png',
#  '/content/Mask_RCNN/images_1/365.png',
#  '/content/Mask_RCNN/images_1/368.png',
#  '/content/Mask_RCNN/images_1/360.png',
#  '/content/Mask_RCNN/images_1/362.png',
#  '/content/Mask_RCNN/images_1/364.png',
#  '/content/Mask_RCNN/images_1/367.png',
#  '/content/Mask_RCNN/images_1/370.png',
#  '/content/Mask_RCNN/images_1/366.png',
#  '/content/Mask_RCNN/images_1/372.png',
#  '/content/Mask_RCNN/images_1/378.png',
#  '/content/Mask_RCNN/images_1/363.png',
#  '/content/Mask_RCNN/images_1/377.png',
#  '/content/Mask_RCNN/images_1/376.png',
#  '/content/Mask_RCNN/images_1/375.png',
#  '/content/Mask_RCNN/images_1/361.png',
#  '/content/Mask_RCNN/images_1/374.png',
#  '/content/Mask_RCNN/images_1/373.png',
#  '/content/Mask_RCNN/images_1/371.png',
#  '/content/Mask_RCNN/images_1/388.png',
#  '/content/Mask_RCNN/images_1/385.png',
#  '/content/Mask_RCNN/images_1/396.png',
#  '/content/Mask_RCNN/images_1/381.png',
#  '/content/Mask_RCNN/images_1/384.png',
#  '/content/Mask_RCNN/images_1/379.png',
#  '/content/Mask_RCNN/images_1/380.png',
#  '/content/Mask_RCNN/images_1/395.png',
#  '/content/Mask_RCNN/images_1/382.png',
#  '/content/Mask_RCNN/images_1/392.png',
#  '/content/Mask_RCNN/images_1/387.png',
#  '/content/Mask_RCNN/images_1/386.png',
#  '/content/Mask_RCNN/images_1/383.png',
#  '/content/Mask_RCNN/images_1/391.png',
#  '/content/Mask_RCNN/images_1/394.png',
#  '/content/Mask_RCNN/images_1/397.png',
#  '/content/Mask_RCNN/images_1/389.png',
#  '/content/Mask_RCNN/images_1/393.png',
#  '/content/Mask_RCNN/images_1/390.png',
#  '/content/Mask_RCNN/images_1/408.png',
#  '/content/Mask_RCNN/images_1/412.png',
#  '/content/Mask_RCNN/images_1/404.png',
#  '/content/Mask_RCNN/images_1/402.png',
#  '/content/Mask_RCNN/images_1/405.png',
#  '/content/Mask_RCNN/images_1/406.png',
#  '/content/Mask_RCNN/images_1/400.png',
#  '/content/Mask_RCNN/images_1/409.png',
#  '/content/Mask_RCNN/images_1/416.png',
#  '/content/Mask_RCNN/images_1/411.png',
#  '/content/Mask_RCNN/images_1/413.png',
#  '/content/Mask_RCNN/images_1/398.png',
#  '/content/Mask_RCNN/images_1/401.png',
#  '/content/Mask_RCNN/images_1/410.png',
#  '/content/Mask_RCNN/images_1/407.png',
#  '/content/Mask_RCNN/images_1/415.png',
#  '/content/Mask_RCNN/images_1/403.png',
#  '/content/Mask_RCNN/images_1/399.png',
#  '/content/Mask_RCNN/images_1/414.png',
#  '/content/Mask_RCNN/images_1/433 (2).png',
#  '/content/Mask_RCNN/images_1/431 (2).png',
#  '/content/Mask_RCNN/images_1/434.png',
#  '/content/Mask_RCNN/images_1/425.png',
#  '/content/Mask_RCNN/images_1/423.png',
#  '/content/Mask_RCNN/images_1/435 (2).png',
#  '/content/Mask_RCNN/images_1/422.png',
#  '/content/Mask_RCNN/images_1/433 (1).png',
#  '/content/Mask_RCNN/images_1/432 (2).png',
#  '/content/Mask_RCNN/images_1/432 (1).png',
#  '/content/Mask_RCNN/images_1/426.png',
#  '/content/Mask_RCNN/images_1/435 (1).png',
#  '/content/Mask_RCNN/images_1/436 (2).png',
#  '/content/Mask_RCNN/images_1/429 (2).png',
#  '/content/Mask_RCNN/images_1/431 (1).png',
#  '/content/Mask_RCNN/images_1/432.png',
#  '/content/Mask_RCNN/images_1/436 (1).png',
#  '/content/Mask_RCNN/images_1/430 (2).png',
#  '/content/Mask_RCNN/images_1/430 (1).png',
#  '/content/Mask_RCNN/images_1/428 (2).png',
#  '/content/Mask_RCNN/images_1/431.png',
#  '/content/Mask_RCNN/images_1/419.png',
#  '/content/Mask_RCNN/images_1/418.png',
#  '/content/Mask_RCNN/images_1/433.png',
#  '/content/Mask_RCNN/images_1/435.png',
#  '/content/Mask_RCNN/images_1/427.png',
#  '/content/Mask_RCNN/images_1/429 (1).png',
#  '/content/Mask_RCNN/images_1/436.png',
#  '/content/Mask_RCNN/images_1/420.png',
#  '/content/Mask_RCNN/images_1/430.png',
#  '/content/Mask_RCNN/images_1/421.png',
#  '/content/Mask_RCNN/images_1/428 (1).png',
#  '/content/Mask_RCNN/images_1/424.png',
#  '/content/Mask_RCNN/images_1/429.png',
#  '/content/Mask_RCNN/images_1/417.png',
#  '/content/Mask_RCNN/images_1/428.png',
#  '/content/Mask_RCNN/images_1/455.png',
#  '/content/Mask_RCNN/images_1/458.png',
#  '/content/Mask_RCNN/images_1/449.png',
#  '/content/Mask_RCNN/images_1/448.png',
#  '/content/Mask_RCNN/images_1/437.png',
#  '/content/Mask_RCNN/images_1/438.png',
#  '/content/Mask_RCNN/images_1/459.png',
#  '/content/Mask_RCNN/images_1/445.png',
#  '/content/Mask_RCNN/images_1/457.png',
#  '/content/Mask_RCNN/images_1/446.png',
#  '/content/Mask_RCNN/images_1/453.png',
#  '/content/Mask_RCNN/images_1/441.png',
#  '/content/Mask_RCNN/images_1/439.png',
#  '/content/Mask_RCNN/images_1/451.png',
#  '/content/Mask_RCNN/images_1/442.png',
#  '/content/Mask_RCNN/images_1/452.png',
#  '/content/Mask_RCNN/images_1/440.png',
#  '/content/Mask_RCNN/images_1/454.png',
#  '/content/Mask_RCNN/images_1/443.png',
#  '/content/Mask_RCNN/images_1/447.png',
#  '/content/Mask_RCNN/images_1/450.png',
#  '/content/Mask_RCNN/images_1/456.png',
#  '/content/Mask_RCNN/images_1/444.png',
#  '/content/Mask_RCNN/images_1/469 (1).png',
#  '/content/Mask_RCNN/images_1/465 (1).png',
#  '/content/Mask_RCNN/images_1/468 (1).png',
#  '/content/Mask_RCNN/images_1/464 (1).png',
#  '/content/Mask_RCNN/images_1/463.png',
#  '/content/Mask_RCNN/images_1/460.png',
#  '/content/Mask_RCNN/images_1/465.png',
#  '/content/Mask_RCNN/images_1/470 (1).png',
#  '/content/Mask_RCNN/images_1/477.png',
#  '/content/Mask_RCNN/images_1/476.png',
#  '/content/Mask_RCNN/images_1/469.png',
#  '/content/Mask_RCNN/images_1/474 (1).png',
#  '/content/Mask_RCNN/images_1/475.png',
#  '/content/Mask_RCNN/images_1/478.png',
#  '/content/Mask_RCNN/images_1/473.png',
#  '/content/Mask_RCNN/images_1/468.png',
#  '/content/Mask_RCNN/images_1/470.png',
#  '/content/Mask_RCNN/images_1/467 (1).png',
#  '/content/Mask_RCNN/images_1/467.png',
#  '/content/Mask_RCNN/images_1/461.png',
#  '/content/Mask_RCNN/images_1/462.png',
#  '/content/Mask_RCNN/images_1/464.png',
#  '/content/Mask_RCNN/images_1/471 (1).png',
#  '/content/Mask_RCNN/images_1/474.png',
#  '/content/Mask_RCNN/images_1/471.png',
#  '/content/Mask_RCNN/images_1/497.png',
#  '/content/Mask_RCNN/images_1/490.png',
#  '/content/Mask_RCNN/images_1/487.png',
#  '/content/Mask_RCNN/images_1/483.png',
#  '/content/Mask_RCNN/images_1/500.png',
#  '/content/Mask_RCNN/images_1/493.png',
#  '/content/Mask_RCNN/images_1/492.png',
#  '/content/Mask_RCNN/images_1/498.png',
#  '/content/Mask_RCNN/images_1/495.png',
#  '/content/Mask_RCNN/images_1/485.png',
#  '/content/Mask_RCNN/images_1/496.png',
#  '/content/Mask_RCNN/images_1/479.png',
#  '/content/Mask_RCNN/images_1/481.png',
#  '/content/Mask_RCNN/images_1/488.png',
#  '/content/Mask_RCNN/images_1/494.png',
#  '/content/Mask_RCNN/images_1/491.png',
#  '/content/Mask_RCNN/images_1/489.png',
#  '/content/Mask_RCNN/images_1/484.png',
#  '/content/Mask_RCNN/images_1/482.png',
#  '/content/Mask_RCNN/images_1/480.png',
#  '/content/Mask_RCNN/images_1/501.png',
#  '/content/Mask_RCNN/images_1/486.png',
#  '/content/Mask_RCNN/images_1/528.png',
#  '/content/Mask_RCNN/images_1/525.png',
#  '/content/Mask_RCNN/images_1/509.png',
#  '/content/Mask_RCNN/images_1/516.png',
#  '/content/Mask_RCNN/images_1/503.png',
#  '/content/Mask_RCNN/images_1/519.png',
#  '/content/Mask_RCNN/images_1/527.png',
#  '/content/Mask_RCNN/images_1/504.png',
#  '/content/Mask_RCNN/images_1/518.png',
#  '/content/Mask_RCNN/images_1/507.png',
#  '/content/Mask_RCNN/images_1/505.png',
#  '/content/Mask_RCNN/images_1/522.png',
#  '/content/Mask_RCNN/images_1/502.png',
#  '/content/Mask_RCNN/images_1/520.png',
#  '/content/Mask_RCNN/images_1/514.png',
#  '/content/Mask_RCNN/images_1/508.png',
#  '/content/Mask_RCNN/images_1/510.png',
#  '/content/Mask_RCNN/images_1/523.png',
#  '/content/Mask_RCNN/images_1/526.png',
#  '/content/Mask_RCNN/images_1/515.png',
#  '/content/Mask_RCNN/images_1/517.png',
#  '/content/Mask_RCNN/images_1/524.png',
#  '/content/Mask_RCNN/images_1/513.png',
#  '/content/Mask_RCNN/images_1/521.png',
#  '/content/Mask_RCNN/images_1/511.png',
#  '/content/Mask_RCNN/images_1/543.png',
#  '/content/Mask_RCNN/images_1/541.png',
#  '/content/Mask_RCNN/images_1/547.png',
#  '/content/Mask_RCNN/images_1/537.png',
#  '/content/Mask_RCNN/images_1/529.png',
#  '/content/Mask_RCNN/images_1/535.png',
#  '/content/Mask_RCNN/images_1/536.png',
#  '/content/Mask_RCNN/images_1/546.png',
#  '/content/Mask_RCNN/images_1/531.png',
#  '/content/Mask_RCNN/images_1/534.png',
#  '/content/Mask_RCNN/images_1/549.png',
#  '/content/Mask_RCNN/images_1/548.png',
#  '/content/Mask_RCNN/images_1/538.png',
#  '/content/Mask_RCNN/images_1/530.png',
#  '/content/Mask_RCNN/images_1/545.png',
#  '/content/Mask_RCNN/images_1/539.png',
#  '/content/Mask_RCNN/images_1/540.png',
#  '/content/Mask_RCNN/images_1/532.png',
#  '/content/Mask_RCNN/images_1/533.png',
#  '/content/Mask_RCNN/images_1/542.png',
#  '/content/Mask_RCNN/images_1/544.png',
#  '/content/Mask_RCNN/images_1/563.png',
#  '/content/Mask_RCNN/images_1/553.png',
#  '/content/Mask_RCNN/images_1/555.png',
#  '/content/Mask_RCNN/images_1/562.png',
#  '/content/Mask_RCNN/images_1/551.png',
#  '/content/Mask_RCNN/images_1/550.png',
#  '/content/Mask_RCNN/images_1/571.png',
#  '/content/Mask_RCNN/images_1/554.png',
#  '/content/Mask_RCNN/images_1/564.png',
#  '/content/Mask_RCNN/images_1/568.png',
#  '/content/Mask_RCNN/images_1/565.png',
#  '/content/Mask_RCNN/images_1/559.png',
#  '/content/Mask_RCNN/images_1/558.png',
#  '/content/Mask_RCNN/images_1/556.png',
#  '/content/Mask_RCNN/images_1/561.png',
#  '/content/Mask_RCNN/images_1/560.png',
#  '/content/Mask_RCNN/images_1/557.png',
#  '/content/Mask_RCNN/images_1/566.png',
#  '/content/Mask_RCNN/images_1/570.png',
#  '/content/Mask_RCNN/images_1/567.png',
#  '/content/Mask_RCNN/images_1/708.png',
#  '/content/Mask_RCNN/images_1/699.png',
#  '/content/Mask_RCNN/images_1/703.png',
#  '/content/Mask_RCNN/images_1/712.png',
#  '/content/Mask_RCNN/images_1/701.png',
#  '/content/Mask_RCNN/images_1/694.png',
#  '/content/Mask_RCNN/images_1/700.png',
#  '/content/Mask_RCNN/images_1/697.png',
#  '/content/Mask_RCNN/images_1/714.png',
#  '/content/Mask_RCNN/images_1/731.png',
#  '/content/Mask_RCNN/images_1/729.png',
#  '/content/Mask_RCNN/images_1/726.png',
#  '/content/Mask_RCNN/images_1/722.png',
#  '/content/Mask_RCNN/images_1/721.png',
#  '/content/Mask_RCNN/images_1/717.png',
#  '/content/Mask_RCNN/images_1/715.png',
#  '/content/Mask_RCNN/images_1/719.png',
#  '/content/Mask_RCNN/images_1/718.png',
#  '/content/Mask_RCNN/images_1/727.png',
#  '/content/Mask_RCNN/images_1/720.png',
#  '/content/Mask_RCNN/images_1/723.png',
#  '/content/Mask_RCNN/images_1/724.png',
#  '/content/Mask_RCNN/images_1/725.png',
#  '/content/Mask_RCNN/images_1/713.png',
#  '/content/Mask_RCNN/images_1/730.png',
#  '/content/Mask_RCNN/images_1/732.png',
#  '/content/Mask_RCNN/images_1/728.png',
#  '/content/Mask_RCNN/images_1/716.png',
#  '/content/Mask_RCNN/images_1/735.png',
#  '/content/Mask_RCNN/images_1/734.png',
#  '/content/Mask_RCNN/images_1/737.png',
#  '/content/Mask_RCNN/images_1/733.png',
#  '/content/Mask_RCNN/images_1/736.png',
#  '/content/Mask_RCNN/images_1/7.png',
#  '/content/Mask_RCNN/images_1/1.png',
#  '/content/Mask_RCNN/images_1/2.png',
#  '/content/Mask_RCNN/images_1/6.png',
#  '/content/Mask_RCNN/images_1/0.png',
#  '/content/Mask_RCNN/images_1/4.png',
#  '/content/Mask_RCNN/images_1/5.png',
#  '/content/Mask_RCNN/images_1/3.png',
#  '/content/Mask_RCNN/images_1/8.png',
#  '/content/Mask_RCNN/images_1/17.png',
#  '/content/Mask_RCNN/images_1/12.png',
#  '/content/Mask_RCNN/images_1/18.png',
#  '/content/Mask_RCNN/images_1/15.png',
#  '/content/Mask_RCNN/images_1/9.png',
#  '/content/Mask_RCNN/images_1/25 (1).png',
#  '/content/Mask_RCNN/images_1/23.png',
#  '/content/Mask_RCNN/images_1/24.png',
#  '/content/Mask_RCNN/images_1/26.png',
#  '/content/Mask_RCNN/images_1/19.png',
#  '/content/Mask_RCNN/images_1/22.png',
#  '/content/Mask_RCNN/images_1/14.png',
#  '/content/Mask_RCNN/images_1/20.png',
#  '/content/Mask_RCNN/images_1/10.png',
#  '/content/Mask_RCNN/images_1/13.png',
#  '/content/Mask_RCNN/images_1/25.png',
#  '/content/Mask_RCNN/images_1/16.png',
#  '/content/Mask_RCNN/images_1/21.png',
#  '/content/Mask_RCNN/images_1/11.png',
#  '/content/Mask_RCNN/images_1/48.png',
#  '/content/Mask_RCNN/images_1/44.png',
#  '/content/Mask_RCNN/images_1/40.png',
#  '/content/Mask_RCNN/images_1/46.png',
#  '/content/Mask_RCNN/images_1/45.png',
#  '/content/Mask_RCNN/images_1/27.png',
#  '/content/Mask_RCNN/images_1/37.png',
#  '/content/Mask_RCNN/images_1/33.png',
#  '/content/Mask_RCNN/images_1/42.png',
#  '/content/Mask_RCNN/images_1/43 (2).png',
#  '/content/Mask_RCNN/images_1/43 (1).png',
#  '/content/Mask_RCNN/images_1/34.png',
#  '/content/Mask_RCNN/images_1/41.png',
#  '/content/Mask_RCNN/images_1/32.png',
#  '/content/Mask_RCNN/images_1/30.png',
#  '/content/Mask_RCNN/images_1/36.png',
#  '/content/Mask_RCNN/images_1/38.png',
#  '/content/Mask_RCNN/images_1/39.png',
#  '/content/Mask_RCNN/images_1/35.png',
#  '/content/Mask_RCNN/images_1/29.png',
#  '/content/Mask_RCNN/images_1/31.png',
#  '/content/Mask_RCNN/images_1/47 (1).png',
#  '/content/Mask_RCNN/images_1/47.png',
#  '/content/Mask_RCNN/images_1/28.png',
#  '/content/Mask_RCNN/images_1/43.png',
#  '/content/Mask_RCNN/images_1/58.png',
#  '/content/Mask_RCNN/images_1/64.png',
#  '/content/Mask_RCNN/images_1/66.png',
#  '/content/Mask_RCNN/images_1/55.png',
#  '/content/Mask_RCNN/images_1/69.png',
#  '/content/Mask_RCNN/images_1/61.png',
#  '/content/Mask_RCNN/images_1/56.png',
#  '/content/Mask_RCNN/images_1/63.png',
#  '/content/Mask_RCNN/images_1/60.png',
#  '/content/Mask_RCNN/images_1/68.png',
#  '/content/Mask_RCNN/images_1/53.png',
#  '/content/Mask_RCNN/images_1/49.png',
#  '/content/Mask_RCNN/images_1/70.png',
#  '/content/Mask_RCNN/images_1/62.png',
#  '/content/Mask_RCNN/images_1/54.png',
#  '/content/Mask_RCNN/images_1/51.png',
#  '/content/Mask_RCNN/images_1/52.png',
#  '/content/Mask_RCNN/images_1/50.png',
#  '/content/Mask_RCNN/images_1/67.png',
#  '/content/Mask_RCNN/images_1/57.png',
#  '/content/Mask_RCNN/images_1/59.png',
#  '/content/Mask_RCNN/images_1/65.png',
#  '/content/Mask_RCNN/images_1/75.png',
#  '/content/Mask_RCNN/images_1/79.png',
#  '/content/Mask_RCNN/images_1/89.png',
#  '/content/Mask_RCNN/images_1/88.png',
#  '/content/Mask_RCNN/images_1/83.png',
#  '/content/Mask_RCNN/images_1/81.png',
#  '/content/Mask_RCNN/images_1/77.png',
#  '/content/Mask_RCNN/images_1/78.png',
#  '/content/Mask_RCNN/images_1/71.png',
#  '/content/Mask_RCNN/images_1/84.png',
#  '/content/Mask_RCNN/images_1/87.png',
#  '/content/Mask_RCNN/images_1/90.png',
#  '/content/Mask_RCNN/images_1/74.png',
#  '/content/Mask_RCNN/images_1/86.png',
#  '/content/Mask_RCNN/images_1/80.png',
#  '/content/Mask_RCNN/images_1/82.png',
#  '/content/Mask_RCNN/images_1/72.png',
#  '/content/Mask_RCNN/images_1/76.png',
#  '/content/Mask_RCNN/images_1/73.png',
#  '/content/Mask_RCNN/images_1/85.png',
#  '/content/Mask_RCNN/images_1/94.png',
#  '/content/Mask_RCNN/images_1/92.png',
#  '/content/Mask_RCNN/images_1/108.png',
#  '/content/Mask_RCNN/images_1/229.png',
#  '/content/Mask_RCNN/images_1/213.png',
#  '/content/Mask_RCNN/images_1/226.png',
#  '/content/Mask_RCNN/images_1/231.png',
#  '/content/Mask_RCNN/images_1/230.png',
#  '/content/Mask_RCNN/images_1/245 (1).png',
#  '/content/Mask_RCNN/images_1/252.png',
#  '/content/Mask_RCNN/images_1/238.png',
#  '/content/Mask_RCNN/images_1/253.png',
#  '/content/Mask_RCNN/images_1/247 (1).png',
#  '/content/Mask_RCNN/images_1/239.png',
#  '/content/Mask_RCNN/images_1/237.png',
#  '/content/Mask_RCNN/images_1/241.png',
#  '/content/Mask_RCNN/images_1/251.png',
#  '/content/Mask_RCNN/images_1/249.png',
#  '/content/Mask_RCNN/images_1/250 (1).png',
#  '/content/Mask_RCNN/images_1/244 (1).png',
#  '/content/Mask_RCNN/images_1/247.png',
#  '/content/Mask_RCNN/images_1/242 (1).png',
#  '/content/Mask_RCNN/images_1/236.png',
#  '/content/Mask_RCNN/images_1/235.png',
#  '/content/Mask_RCNN/images_1/245.png',
#  '/content/Mask_RCNN/images_1/250.png',
#  '/content/Mask_RCNN/images_1/244.png',
#  '/content/Mask_RCNN/images_1/243.png',
#  '/content/Mask_RCNN/images_1/246.png',
#  '/content/Mask_RCNN/images_1/242.png',
#  '/content/Mask_RCNN/images_1/233.png',
#  '/content/Mask_RCNN/images_1/240.png',
#  '/content/Mask_RCNN/images_1/234.png',
#  '/content/Mask_RCNN/images_1/266.png',
#  '/content/Mask_RCNN/images_1/270.png',
#  '/content/Mask_RCNN/images_1/259.png',
#  '/content/Mask_RCNN/images_1/271.png',
#  '/content/Mask_RCNN/images_1/258.png',
#  '/content/Mask_RCNN/images_1/257.png',
#  '/content/Mask_RCNN/images_1/265.png',
#  '/content/Mask_RCNN/images_1/264.png',
#  '/content/Mask_RCNN/images_1/263.png',
#  '/content/Mask_RCNN/images_1/254.png',
#  '/content/Mask_RCNN/images_1/267.png',
#  '/content/Mask_RCNN/images_1/268.png',
#  '/content/Mask_RCNN/images_1/269.png',
#  '/content/Mask_RCNN/images_1/256.png',
#  '/content/Mask_RCNN/images_1/272.png',
#  '/content/Mask_RCNN/images_1/262.png',
#  '/content/Mask_RCNN/images_1/261.png',
#  '/content/Mask_RCNN/images_1/255.png',
#  '/content/Mask_RCNN/images_1/282.png',
#  '/content/Mask_RCNN/images_1/289.png',
#  '/content/Mask_RCNN/images_1/288.png',
#  '/content/Mask_RCNN/images_1/294.png',
#  '/content/Mask_RCNN/images_1/276.png',
#  '/content/Mask_RCNN/images_1/287.png',
#  '/content/Mask_RCNN/images_1/292.png',
#  '/content/Mask_RCNN/images_1/293.png',
#  '/content/Mask_RCNN/images_1/280.png',
#  '/content/Mask_RCNN/images_1/281.png',
#  '/content/Mask_RCNN/images_1/277.png',
#  '/content/Mask_RCNN/images_1/286.png',
#  '/content/Mask_RCNN/images_1/291.png',
#  '/content/Mask_RCNN/images_1/284.png',
#  '/content/Mask_RCNN/images_1/275.png',
#  '/content/Mask_RCNN/images_1/283.png',
#  '/content/Mask_RCNN/images_1/285.png']

# %%
import os
def extract_boxes(filename):
        # load and parse the file
        tree = ElementTree.parse(filename)
        # get the root of the document
        root = tree.getroot()
        # extract each bounding box
        boxes = list()
        for box in root.findall('.//bndbox'):
            xmin = int(box.find('xmin').text)
            ymin = int(box.find('ymin').text)
            xmax = int(box.find('xmax').text)
            ymax = int(box.find('ymax').text)
            coors = [xmin, ymin, xmax, ymax]
            boxes.append(coors)
        # extract image dimensions
        ##print(boxes)
        width = int(root.find('.//size/width').text)
        height = int(root.find('.//size/height').text)
        return boxes, width, height
class FishDataset(Dataset):
    # load the dataset definitions
    def load_dataset(self, dataset_dir, is_train=True):
        # define one class
        self.add_class("dataset", 1, "fish")
        # define data locations
        images_dir = dataset_dir + '//images_1//'
        annotations_dir = dataset_dir + '//annotations//'
        image_paths = [os.path.join(images_dir, f) for f in os.listdir(images_dir) if f.endswith('.png')]
        # find all images
        a=0
        for filename in image_paths:
            # extract image id
            s=str(filename).split("/");
            name_image=s[len(s)-1].split(".")
            image_id = name_image[0]
            # skip all images after 150 if we are building the train set
            if is_train and int(image_id)  >= 580:
                continue
            # skip all images before 650 if we are building the test/val set
            if not is_train and int(image_id)  < 580:
                continue
            
            img_path = filename
            ann_path = annotations_dir + image_id + '.xml'
            # add to dataset
            self.add_image('dataset', image_id=image_id, path=img_path, annotation=ann_path)
            
    
    # load the masks for an image
    def load_mask(self, image_id):
        # get details of image
        info = self.image_info[image_id]
        # define box file location
        path = info["annotation"]
        # load XML
        boxes, w, h =extract_boxes(path)
        # create one array for all masks, each on a different channel
        masks = zeros([h, w, len(boxes)], dtype='uint8')
        # create masks
        class_ids = list()
        for i in range(len(boxes)):
            box = boxes[i]
            row_s, row_e = box[1], box[3]
            col_s, col_e = box[0], box[2]
            masks[row_s:row_e, col_s:col_e, i] = 1
            class_ids.append(self.class_names.index('fish'))
        return masks, asarray(class_ids, dtype='int32')

    # load an image reference
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        ##print(info['path'])
        return info['path']
#dfine a configuration for the model
class FishConfig(Config):
	# Give the configuration a recognizable name
	NAME = "fish_cfg"
	# Number of classes (background + kangaroo)
	NUM_CLASSES = 1 + 1
	# Number of training steps per epoch
	STEPS_PER_EPOCH = 11
    
# define the prediction configuration
class PredictionConfig(Config):
    # define the name of the configuration
    NAME = "fish_cfg"
    # number of classes (background + kangaroo)
    NUM_CLASSES = 1 + 1
    # simplify GPU config
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

# %%
def evaluate_model(dataset, model, cfg):
	APs = list()
	for image_id in dataset.image_ids:
		# load image, bounding boxes and masks for the image id
		image, image_meta, gt_class_id, gt_bbox, gt_mask = load_image_gt(dataset, cfg, image_id, use_mini_mask=False)
		# convert pixel values (e.g. center)
		scaled_image = mold_image(image, cfg)
		# convert image into one sample
		sample = expand_dims(scaled_image, 0)
		# make prediction
		yhat = model.detect(sample, verbose=0)
		# extract results for first sample
		r = yhat[0]
		# calculate statistics, including AP
		AP, _, _, _ = compute_ap(gt_bbox, gt_class_id, gt_mask, r["rois"], r["class_ids"], r["scores"], r['masks'])
		# store
		APs.append(AP)
	# calculate the mean AP across all images
	mAP = mean(APs)
	return mAP

# %%
print("hh")
# Out:
# hh

# %%
# prepare train set
# train set
train_set = FishDataset()
train_set.load_dataset(".", is_train=True)
train_set.prepare()
print('Train: %d' % len(train_set.image_ids))
# test/val set
test_set = FishDataset()
test_set.load_dataset(".", is_train=False)
test_set.prepare()
print('Test: %d' % len(test_set.image_ids))
# prepare config
config = FishConfig()
config.display()
# Out:
# /content/Mask_RCNN
# Train: 567
# Test: 155
#
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           fish_cfg
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                11
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
import requests
url = "https://github.com/matterport/Mask_RCNN/releases/download/v2.0/mask_rcnn_coco.h5"
r = requests.get(url)
# Out:
# /content/Mask_RCNN

# %%
# %cd /content/Mask_RCNN
import requests
url = "https://github.com/matterport/Mask_RCNN/releases/download/v2.0/mask_rcnn_coco.h5"

downloaded_obj = requests.get(url)


with open("mask_rcnn_coco.h5", "wb") as file:

    file.write(downloaded_obj.content)
# Out:
# /content/Mask_RCNN

# %%
# Out:
# /content
# /content/Mask_RCNN

# %%
# Out:
# /content/drive
# /content/drive

# %%
model = MaskRCNN(mode='training', model_dir='.', config=config)
# load weights (mscoco) and exclude the output layers
model.load_weights('mask_rcnn_coco.h5', by_name=True, exclude=["mrcnn_class_logits", "mrcnn_bbox_fc",  "mrcnn_bbox", "mrcnn_mask"])
# train weights (output layers or 'heads')
model.train(train_set, test_set, learning_rate=config.LEARNING_RATE, epochs=20, layers='heads')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: ./fish_cfg20200810T1200/mask_rcnn_fish_cfg_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:49: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/20
# 11/11 [==============================] - 159s 14s/step - loss: 2.0856 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.3456 - mrcnn_class_loss: 0.1283 - mrcnn_bbox_loss: 0.9373 - mrcnn_mask_loss: 0.6671 - val_loss: 1.7266 - val_rpn_class_loss: 0.0185 - val_rpn_bbox_loss: 0.2920 - val_mrcnn_class_loss: 0.0884 - val_mrcnn_bbox_loss: 0.7939 - val_mrcnn_mask_loss: 0.5338
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1265: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/20
# 11/11 [==============================] - 77s 7s/step - loss: 1.3865 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.2230 - mrcnn_class_loss: 0.0526 - mrcnn_bbox_loss: 0.6561 - mrcnn_mask_loss: 0.4517 - val_loss: 1.2852 - val_rpn_class_loss: 0.0071 - val_rpn_bbox_loss: 0.2266 - val_mrcnn_class_loss: 0.0469 - val_mrcnn_bbox_loss: 0.5876 - val_mrcnn_mask_loss: 0.4169
# Epoch 3/20
# 11/11 [==============================] - 77s 7s/step - loss: 1.2566 - rpn_class_loss: 0.0440 - rpn_bbox_loss: 0.1959 - mrcnn_class_loss: 0.1150 - mrcnn_bbox_loss: 0.5199 - mrcnn_mask_loss: 0.3817 - val_loss: 1.1229 - val_rpn_class_loss: 0.0057 - val_rpn_bbox_loss: 0.2380 - val_mrcnn_class_loss: 0.0699 - val_mrcnn_bbox_loss: 0.4280 - val_mrcnn_mask_loss: 0.3813
# Epoch 4/20
# 11/11 [==============================] - 77s 7s/step - loss: 1.2574 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.2487 - mrcnn_class_loss: 0.0817 - mrcnn_bbox_loss: 0.4725 - mrcnn_mask_loss: 0.4503 - val_loss: 1.0852 - val_rpn_class_loss: 0.0097 - val_rpn_bbox_loss: 0.2303 - val_mrcnn_class_loss: 0.0550 - val_mrcnn_bbox_loss: 0.4283 - val_mrcnn_mask_loss: 0.3618
# Epoch 5/20
# 11/11 [==============================] - 77s 7s/step - loss: 1.0330 - rpn_class_loss: 0.0096 - rpn_bbox_loss: 0.1966 - mrcnn_class_loss: 0.0335 - mrcnn_bbox_loss: 0.4088 - mrcnn_mask_loss: 0.3846 - val_loss: 1.1876 - val_rpn_class_loss: 0.0085 - val_rpn_bbox_loss: 0.2752 - val_mrcnn_class_loss: 0.0495 - val_mrcnn_bbox_loss: 0.5097 - val_mrcnn_mask_loss: 0.3448
# Epoch 6/20
# 11/11 [==============================] - 78s 7s/step - loss: 0.9840 - rpn_class_loss: 0.0087 - rpn_bbox_loss: 0.2140 - mrcnn_class_loss: 0.0670 - mrcnn_bbox_loss: 0.3954 - mrcnn_mask_loss: 0.2989 - val_loss: 1.0685 - val_rpn_class_loss: 0.0085 - val_rpn_bbox_loss: 0.2607 - val_mrcnn_class_loss: 0.0568 - val_mrcnn_bbox_loss: 0.4190 - val_mrcnn_mask_loss: 0.3234
# Epoch 7/20
# 11/11 [==============================] - 78s 7s/step - loss: 0.9501 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.2498 - mrcnn_class_loss: 0.0191 - mrcnn_bbox_loss: 0.3537 - mrcnn_mask_loss: 0.3246 - val_loss: 0.9827 - val_rpn_class_loss: 0.0110 - val_rpn_bbox_loss: 0.2381 - val_mrcnn_class_loss: 0.0567 - val_mrcnn_bbox_loss: 0.3669 - val_mrcnn_mask_loss: 0.3100
# Epoch 8/20
# 11/11 [==============================] - 78s 7s/step - loss: 0.9621 - rpn_class_loss: 0.0087 - rpn_bbox_loss: 0
- rpn_class_loss: 0.0143 - rpn_bbox_loss: 0.2571 - mrcnn_class_loss: 0.0787 - mrcnn_bbox_loss: 0.2886 - mrcnn_mask_loss: 0.2675 - val_loss: 0.8028 - val_rpn_class_loss: 0.0105 - val_rpn_bbox_loss: 0.2291 - val_mrcnn_class_loss: 0.0601 - val_mrcnn_bbox_loss: 0.2531 - val_mrcnn_mask_loss: 0.2499
# Epoch 17/20
# 11/11 [==============================] - 77s 7s/step - loss: 0.8631 - rpn_class_loss: 0.0101 - rpn_bbox_loss: 0.2276 - mrcnn_class_loss: 0.0685 - mrcnn_bbox_loss: 0.3040 - mrcnn_mask_loss: 0.2530 - val_loss: 0.8551 - val_rpn_class_loss: 0.0090 - val_rpn_bbox_loss: 0.2452 - val_mrcnn_class_loss: 0.0554 - val_mrcnn_bbox_loss: 0.2819 - val_mrcnn_mask_loss: 0.2637
# Epoch 18/20
# 11/11 [==============================] - 77s 7s/step - loss: 1.2347 - rpn_class_loss: 0.0107 - rpn_bbox_loss: 0.3665 - mrcnn_class_loss: 0.1008 - mrcnn_bbox_loss: 0.4022 - mrcnn_mask_loss: 0.3545 - val_loss: 0.8839 - val_rpn_class_loss: 0.0132 - val_rpn_bbox_loss: 0.2505 - val_mrcnn_class_loss: 0.0722 - val_mrcnn_bbox_loss: 0.2690 - val_mrcnn_mask_loss: 0.2789
# Epoch 19/20
# 11/11 [==============================] - 78s 7s/step - loss: 0.9873 - rpn_class_loss: 0.0093 - rpn_bbox_loss: 0.2793 - mrcnn_class_loss: 0.0952 - mrcnn_bbox_loss: 0.3003 - mrcnn_mask_loss: 0.3034 - val_loss: 0.9544 - val_rpn_class_loss: 0.0089 - val_rpn_bbox_loss: 0.3191 - val_mrcnn_class_loss: 0.0639 - val_mrcnn_bbox_loss: 0.2995 - val_mrcnn_mask_loss: 0.2630
# Epoch 20/20
# 11/11 [==============================] - 77s 7s/step - loss: 0.6999 - rpn_class_loss: 0.0115 - rpn_bbox_loss: 0.2000 - mrcnn_class_loss: 0.0594 - mrcnn_bbox_loss: 0.1888 - mrcnn_mask_loss: 0.2402 - val_loss: 0.8586 - val_rpn_class_loss: 0.0091 - val_rpn_bbox_loss: 0.2835 - val_mrcnn_class_loss: 0.0647 - val_mrcnn_bbox_loss: 0.2613 - val_mrcnn_mask_loss: 0.2400

# %%
cfg = PredictionConfig()
# define the model
model = MaskRCNN(mode='inference', model_dir='./', config=cfg)
# load model weights
model.load_weights('./fish_cfg20200810T1200/mask_rcnn_fish_cfg_0020.h5', by_name=True)
# evaluate model on training dataset
train_mAP = evaluate_model(train_set, model, cfg)
print("Train mAP: %.3f" % train_mAP)
# evaluate model on test dataset
test_mAP = evaluate_model(test_set, model, cfg)
print("Test mAP: %.3f" % test_mAP)
# Out:
# Re-starting from epoch 20
# Train mAP: 0.776
# Test mAP: 0.822

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
#jpgfile = Image.open("picture.jpg") 
image = load_img("383.png")
image = img_to_array(image)
data = np.array(image, dtype="int32")
##print(data)

# %%
# example of making a prediction
from PIL import Image 
##jpgfile = Image.open("picture.jpg") 
# load image
#image = Image.open("273.png")
#image=train_set.load_image(33)
#print(image)
# convert pixel values (e.g. center)
from matplotlib import pyplot
from matplotlib.patches import Rectangle
# convert pixel values (e.g. center)
scaled_image = mold_image(data,config)
# convert image into one sample
sample = expand_dims(scaled_image, 0)
# make prediction
yhat = model.detect(sample, verbose=0)[0]
# get the context for drawing boxes
#pyplot.subplot(n_images, 2, i*2+2)
# plot raw pixel data
pyplot.imshow(data)
pyplot.title('Predicted')
ax = pyplot.gca()
# plot each box
for box in yhat['rois']:
	# get coordinates
	y1, x1, y2, x2 = box
	# calculate width and height of the box
	width, height = x2 - x1, y2 - y1
	# create the shape
	rect = Rectangle((x1, y1), width, height, fill=False, color='red')
	# draw the box
	ax.add_patch(rect)
